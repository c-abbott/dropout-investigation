# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
import os
import json
from mlp.data_providers import MNISTDataProvider, EMNISTDataProvider

# Seed a random number generator
seed = 11102019 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

FIGURES_PATH = '/Users/callum/dropout-investigation/results/figures'
DATA_PATH = '/Users/callum/dropout-investigation/results/network_data'

# Create data provider objects for the MNIST data set
train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fc26077e910>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fc26077e910>)

# %% [markdown]
# # Width Investigation

# %%
sl_outputs = {}

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim = 784, 47
hidden_dims = [32, 64, 128]

for hidden_dim in hidden_dims:
    train_data.reset()
    valid_data.reset()
    weights_init = GlorotUniformInit(rng=rng)
    biases_init = ConstantInit(0.)
    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)

    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
    
    fig_1.savefig(os.path.join(FIGURES_PATH, f'err_SL_{hidden_dim}.png'))
    fig_2.savefig(os.path.join(FIGURES_PATH, f'acc_SL_{hidden_dim}.png'))
    sl_outputs[f'{hidden_dim}_SL'] = [stats.tolist(), keys, run_time]
    
with open(os.path.join(DATA_PATH, f'SL_width_data'), 'w+') as f:
    json.dump(sl_outputs, f)
# Out:
# ...
# Epoch 1: 0.8s to complete
#     error(train)=1.21e+00, acc(train)=6.45e-01, error(valid)=1.23e+00, acc(valid)=6.41e-01
# ...
# Epoch 2: 0.8s to complete
#     error(train)=9.54e-01, acc(train)=7.13e-01, error(valid)=9.69e-01, acc(valid)=7.08e-01
# ...
# Epoch 3: 0.8s to complete
#     error(train)=8.80e-01, acc(train)=7.30e-01, error(valid)=8.98e-01, acc(valid)=7.25e-01
# ...
# Epoch 4: 0.8s to complete
#     error(train)=8.04e-01, acc(train)=7.51e-01, error(valid)=8.27e-01, acc(valid)=7.43e-01
# ...
# Epoch 5: 0.8s to complete
#     error(train)=7.60e-01, acc(train)=7.66e-01, error(valid)=7.90e-01, acc(valid)=7.56e-01
# ...
# Epoch 6: 0.8s to complete
#     error(train)=7.04e-01, acc(train)=7.80e-01, error(valid)=7.36e-01, acc(valid)=7.69e-01
# ...
# Epoch 7: 0.8s to complete
#     error(train)=6.86e-01, acc(train)=7.84e-01, error(valid)=7.24e-01, acc(valid)=7.76e-01
# ...
# Epoch 8: 0.8s to complete
#     error(train)=6.70e-01, acc(train)=7.87e-01, error(valid)=7.11e-01, acc(valid)=7.79e-01
# ...
# Epoch 9: 0.8s to complete
# ...

# %% [markdown]
# # Depth Investigation

# %% [markdown]
# # 1 Layer

# %%
depth_outputs = {}

# %%
depth_outputs
# Out:
# {'depth_2L': [0.1,
#   [[3.870274700089126,
#     0.020029999999999916,
#     3.8718727735635388,
#     0.017911392405063276],
#    [0.8543955256461231,
#     0.7373300000000029,
#     0.8669940688931809,
#     0.7317721518987338],
#    [0.6394134728676681,
#     0.7952999999999976,
#     0.6725637542234028,
#     0.7854430379746834],
#    [0.5717295465431166,
#     0.8072399999999981,
#     0.6168853431492198,
#     0.7944303797468354],
#    [0.5080498987015495,
#     0.8305100000000016,
#     0.5630701752293381,
#     0.8136708860759495],
#    [0.47544829673203065,
#     0.8379600000000018,
#     0.5479293201532881,
#     0.8185443037974679],
#    [0.4406917356280719,
#     0.848580000000003,
#     0.5156342962565548,
#     0.8274050632911389],
#    [0.40729518589577385,
#     0.8592100000000019,
#     0.4984808658120375,
#     0.8333544303797468],
#    [0.390180356122103,
#     0.8643600000000008,
#     0.4870822545223732,
#     0.8381645569620249],
#    [0.3929570644931217,
# ...

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser


# Setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

train_data.reset()
valid_data.reset()
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
depth_outputs[f'depth_1L'] = [learning_rate, stats.tolist(), keys, run_time]
fig_1.savefig(os.path.join(FIGURES_PATH, f'err_depth_1L'))
fig_2.savefig(os.path.join(FIGURES_PATH, f'acc_depth_1L'))
with open(os.path.join(DATA_PATH, f'1L_depth_data'), 'w+') as f:
    json.dump(depth_outputs, f)
# Out:
# ...
# Epoch 1: 1.5s to complete
#     error(train)=9.17e-01, acc(train)=7.26e-01, error(valid)=9.28e-01, acc(valid)=7.24e-01
# ...
# Epoch 2: 1.6s to complete
#     error(train)=7.10e-01, acc(train)=7.81e-01, error(valid)=7.28e-01, acc(valid)=7.77e-01
# ...
# Epoch 3: 1.4s to complete
#     error(train)=6.05e-01, acc(train)=8.06e-01, error(valid)=6.33e-01, acc(valid)=8.01e-01
# ...
# Epoch 4: 1.4s to complete
#     error(train)=5.53e-01, acc(train)=8.20e-01, error(valid)=5.95e-01, acc(valid)=8.09e-01
# ...
# Epoch 5: 1.4s to complete
#     error(train)=5.02e-01, acc(train)=8.37e-01, error(valid)=5.56e-01, acc(valid)=8.23e-01
# ...
# Epoch 6: 1.5s to complete
#     error(train)=4.72e-01, acc(train)=8.44e-01, error(valid)=5.32e-01, acc(valid)=8.28e-01
# ...
# Epoch 7: 1.5s to complete
#     error(train)=4.48e-01, acc(train)=8.49e-01, error(valid)=5.18e-01, acc(valid)=8.29e-01
# ...
# Epoch 8: 1.5s to complete
#     error(train)=4.34e-01, acc(train)=8.51e-01, error(valid)=5.07e-01, acc(valid)=8.32e-01
# ...
# Epoch 9: 1.5s to complete
# ...

# %% [markdown]
# # 2 Layer

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser


# Setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

train_data.reset()
valid_data.reset()
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

depth_outputs[f'depth_2L'] = [learning_rate, stats.tolist(), keys, run_time]

fig_1.savefig(os.path.join(FIGURES_PATH, f'err_depth_2L'))
fig_2.savefig(os.path.join(FIGURES_PATH, f'acc_depth_2L'))

with open(os.path.join(DATA_PATH, f'2L_depth_data'), 'w+') as f:
    json.dump(depth_outputs, f)
# Out:
# ...
# Epoch 1: 1.8s to complete
#     error(train)=8.54e-01, acc(train)=7.37e-01, error(valid)=8.67e-01, acc(valid)=7.32e-01
# ...
# Epoch 2: 1.7s to complete
#     error(train)=6.39e-01, acc(train)=7.95e-01, error(valid)=6.73e-01, acc(valid)=7.85e-01
# ...
# Epoch 3: 1.8s to complete
#     error(train)=5.72e-01, acc(train)=8.07e-01, error(valid)=6.17e-01, acc(valid)=7.94e-01
# ...
# Epoch 4: 1.8s to complete
#     error(train)=5.08e-01, acc(train)=8.31e-01, error(valid)=5.63e-01, acc(valid)=8.14e-01
# ...
# Epoch 5: 1.8s to complete
#     error(train)=4.75e-01, acc(train)=8.38e-01, error(valid)=5.48e-01, acc(valid)=8.19e-01
# ...
# Epoch 6: 1.8s to complete
#     error(train)=4.41e-01, acc(train)=8.49e-01, error(valid)=5.16e-01, acc(valid)=8.27e-01
# ...
# Epoch 7: 1.8s to complete
#     error(train)=4.07e-01, acc(train)=8.59e-01, error(valid)=4.98e-01, acc(valid)=8.33e-01
# ...
# Epoch 8: 1.8s to complete
#     error(train)=3.90e-01, acc(train)=8.64e-01, error(valid)=4.87e-01, acc(valid)=8.38e-01
# ...
# Epoch 9: 1.8s to complete
# ...

# %% [markdown]
# # 3 Layer

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

train_data.reset()
valid_data.reset()
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)


#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

depth_outputs[f'depth_3L'] = [learning_rate, stats.tolist(), keys, run_time]

fig_1.savefig(os.path.join(FIGURES_PATH, f'err_depth_3L'))
fig_2.savefig(os.path.join(FIGURES_PATH, f'acc_depth_3L'))

with open(os.path.join(DATA_PATH, f'3L_depth_data'), 'w+') as f:
    json.dump(depth_outputs, f)
# Out:
# ...
# Epoch 1: 1.9s to complete
#     error(train)=9.22e-01, acc(train)=7.10e-01, error(valid)=9.49e-01, acc(valid)=7.03e-01
# ...
# Epoch 2: 1.7s to complete
#     error(train)=6.40e-01, acc(train)=7.86e-01, error(valid)=6.76e-01, acc(valid)=7.78e-01
# ...
# Epoch 3: 1.7s to complete
#     error(train)=5.25e-01, acc(train)=8.25e-01, error(valid)=5.76e-01, acc(valid)=8.11e-01
# ...
# Epoch 4: 1.7s to complete
#     error(train)=5.13e-01, acc(train)=8.22e-01, error(valid)=5.82e-01, acc(valid)=8.04e-01
# ...
# Epoch 5: 1.8s to complete
#     error(train)=4.46e-01, acc(train)=8.47e-01, error(valid)=5.21e-01, acc(valid)=8.27e-01
# ...
# Epoch 6: 1.9s to complete
#     error(train)=4.14e-01, acc(train)=8.56e-01, error(valid)=5.04e-01, acc(valid)=8.33e-01
# ...
# Epoch 7: 1.7s to complete
#     error(train)=4.02e-01, acc(train)=8.58e-01, error(valid)=5.09e-01, acc(valid)=8.29e-01
# ...
# Epoch 8: 1.7s to complete
#     error(train)=3.94e-01, acc(train)=8.60e-01, error(valid)=5.07e-01, acc(valid)=8.32e-01
# ...
# Epoch 9: 1.7s to complete
# ...

# %% [markdown]
# # Learning Rate Tuning

# %%
lr_outputs = {}

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

learning_rates = [1e-2, 3e-2, 1e-1, 3e-1, 1.0, 3.0]

for learning_rate in learning_rates:
    train_data.reset()
    valid_data.reset()
    weights_init = GlorotUniformInit(rng=rng)
    biases_init = ConstantInit(0.)
    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)

    # Remember to use notebook=False when you write a script to be run in a terminal
    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

    lr_outputs[f'lr_{learning_rate}'] = [learning_rate, stats.tolist(), keys, run_time]

    fig_1.savefig(os.path.join(FIGURES_PATH, f'err_lr_{learning_rate}_.png'))
    fig_2.savefig(os.path.join(FIGURES_PATH, f'acc_lr_{learning_rate}_.png'))

with open(os.path.join(DATA_PATH, f'lr_data'), 'w+') as f:
    json.dump(lr_outputs, f)
# Out:
# ...
# Epoch 1: 1.7s to complete
#     error(train)=2.28e+00, acc(train)=4.00e-01, error(valid)=2.28e+00, acc(valid)=3.96e-01
# ...
# Epoch 2: 1.6s to complete
#     error(train)=1.43e+00, acc(train)=5.96e-01, error(valid)=1.43e+00, acc(valid)=5.93e-01
# ...
# Epoch 3: 1.6s to complete
#     error(train)=1.19e+00, acc(train)=6.56e-01, error(valid)=1.20e+00, acc(valid)=6.51e-01
# ...
# Epoch 4: 1.7s to complete
#     error(train)=1.05e+00, acc(train)=6.96e-01, error(valid)=1.06e+00, acc(valid)=6.92e-01
# ...
# Epoch 5: 1.7s to complete
#     error(train)=9.42e-01, acc(train)=7.20e-01, error(valid)=9.51e-01, acc(valid)=7.14e-01
# ...
# Epoch 6: 1.7s to complete
#     error(train)=8.81e-01, acc(train)=7.40e-01, error(valid)=8.94e-01, acc(valid)=7.32e-01
# ...
# Epoch 7: 1.7s to complete
#     error(train)=8.20e-01, acc(train)=7.53e-01, error(valid)=8.35e-01, acc(valid)=7.47e-01
# ...
# Epoch 8: 1.7s to complete
#     error(train)=7.72e-01, acc(train)=7.67e-01, error(valid)=7.90e-01, acc(valid)=7.58e-01
# ...
# Epoch 9: 1.7s to complete
# ...

# %% [markdown]
# # Task 2

# %% [markdown]
# * Discover the best possible network configuration, when the only available options to choose from are Dropout and Weight Penalty functions and the hyper-parameters (**learning rate, Dropout Probability and penalty coefficient for the Weight Penalty functions**)

# %% [markdown]
# * The Dropout probability is a float value in the range (0,1), e.g. 0.5, chosen manually. Penalty coefficient is also a manually selected float value, e.g. 0.001, usually in the range of 0.1 − 0.00001 .
#
#
# * For model selection, you should use validation performance to pick the best model and finally report test performance of the best model.
#
#
# * Ensure that you thoroughly describe how these functions affect performance when used together and separately with different hyperparameters in your report, ideally both at the theoretical and empirical level. Note that the expected amount of work in this part is not a brute-force exploration of all possible variations of network configurations and hyperparameters but a carefully designed set of experiments that provides meaningful analysis and insights.

# %% [markdown]
# ## Dropout Investigation

# %%
dropout_outputs = {}

# %%
dropoutless_outputs = {}

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

incl_probs = [0.95, 0.9, 0.85, 0.8, 0.75]
share_across_batch = [True, False]

for incl_prob in incl_probs:
    for share in share_across_batch:
        train_data.reset()
        valid_data.reset()
        weights_init = GlorotUniformInit(rng=rng)
        biases_init = ConstantInit(0.)
        model = MultipleLayerModel([
            AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
            ReluLayer(),
            AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng, share_across_batch=share),
            AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng, share_across_batch=share),
            AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng, share_across_batch=share),
            AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
        error = CrossEntropySoftmaxError()
        # Use a basic gradient descent learning rule
        learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)

        # Remember to use notebook=False when you write a script to be run in a terminal
        stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
            model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

        dropoutless_outputs[f'DO_{incl_prob}_{share}_inputless'] = [incl_prob, share, stats.tolist(), keys, run_time]

        fig_1.savefig(os.path.join(FIGURES_PATH, f'err_DO_{incl_prob}_{share}_inputless.png'))
        fig_2.savefig(os.path.join(FIGURES_PATH, f'acc_DO_{incl_prob}_{share}_inputless.png'))

with open(os.path.join(DATA_PATH, f'DO_data_inputless'), 'w+') as f:
    json.dump(dropoutless_outputs, f)
# Out:
# ...
# Epoch 1: 2.0s to complete
#     error(train)=9.21e-01, acc(train)=7.06e-01, error(valid)=9.35e-01, acc(valid)=7.03e-01
# ...
# Epoch 2: 2.1s to complete
#     error(train)=6.86e-01, acc(train)=7.76e-01, error(valid)=7.05e-01, acc(valid)=7.73e-01
# ...
# Epoch 3: 2.0s to complete
#     error(train)=5.72e-01, acc(train)=8.10e-01, error(valid)=6.09e-01, acc(valid)=8.01e-01
# ...
# Epoch 4: 2.0s to complete
#     error(train)=5.18e-01, acc(train)=8.27e-01, error(valid)=5.71e-01, acc(valid)=8.18e-01
# ...
# Epoch 5: 2.0s to complete
#     error(train)=4.88e-01, acc(train)=8.33e-01, error(valid)=5.42e-01, acc(valid)=8.17e-01
# ...
# Epoch 6: 2.4s to complete
#     error(train)=4.41e-01, acc(train)=8.48e-01, error(valid)=5.11e-01, acc(valid)=8.31e-01
# ...
# Epoch 7: 1.9s to complete
#     error(train)=4.17e-01, acc(train)=8.55e-01, error(valid)=4.93e-01, acc(valid)=8.35e-01
# ...
# Epoch 8: 1.9s to complete
#     error(train)=4.19e-01, acc(train)=8.53e-01, error(valid)=5.03e-01, acc(valid)=8.33e-01
# ...
# Epoch 9: 1.9s to complete
# ...

# %% [markdown]
# ## L1 Investigation

# %%
L1_outputs = {}

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser
from mlp.penalties import L1Penalty

# Setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128


penalty_coeffs = [0.00002, 0.00004, 0.00005]

for penalty_coeff in penalty_coeffs:
    train_data.reset()
    valid_data.reset()
    weights_init = GlorotUniformInit(rng=rng)
    biases_init = ConstantInit(0.)
    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)), 
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)),
])
    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)

    # Remember to use notebook=False when you write a script to be run in a terminal
    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

    L1_outputs[f'L1_{penalty_coeff}'] = [penalty_coeff, stats.tolist(), keys, run_time]

    fig_1.savefig(os.path.join(FIGURES_PATH, f'err_L1_{penalty_coeff}.png'))
    fig_2.savefig(os.path.join(FIGURES_PATH, f'acc_L1_{penalty_coeff}.png'))

with open(os.path.join(DATA_PATH, f'L1_data'), 'w+') as f:
    json.dump(L1_outputs, f)
# Out:
# ...
# Epoch 1: 2.6s to complete
#     error(train)=8.56e-01, acc(train)=7.36e-01, error(valid)=8.74e-01, acc(valid)=7.29e-01
# ...
# Epoch 2: 2.8s to complete
#     error(train)=6.38e-01, acc(train)=7.96e-01, error(valid)=6.65e-01, acc(valid)=7.89e-01
# ...
# Epoch 3: 2.8s to complete
#     error(train)=5.66e-01, acc(train)=8.10e-01, error(valid)=6.06e-01, acc(valid)=7.96e-01
# ...
# Epoch 4: 2.9s to complete
#     error(train)=5.07e-01, acc(train)=8.27e-01, error(valid)=5.60e-01, acc(valid)=8.13e-01
# ...
# Epoch 5: 2.8s to complete
#     error(train)=5.17e-01, acc(train)=8.19e-01, error(valid)=5.87e-01, acc(valid)=8.02e-01
# ...
# Epoch 6: 2.8s to complete
#     error(train)=4.33e-01, acc(train)=8.48e-01, error(valid)=5.09e-01, acc(valid)=8.27e-01
# ...
# Epoch 7: 2.9s to complete
#     error(train)=4.09e-01, acc(train)=8.56e-01, error(valid)=4.95e-01, acc(valid)=8.33e-01
# ...
# Epoch 8: 3.0s to complete
#     error(train)=4.24e-01, acc(train)=8.45e-01, error(valid)=5.24e-01, acc(valid)=8.20e-01
# ...
# Epoch 9: 2.9s to complete
# ...

# %% [markdown]
# # L2 Investigation

# %%
L2_outputs = {}

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser
from mlp.penalties import L2Penalty

# Setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128


penalty_coeffs = [0.002, 0.0008]

for penalty_coeff in penalty_coeffs:
    train_data.reset()
    valid_data.reset()
    weights_init = GlorotUniformInit(rng=rng)
    biases_init = ConstantInit(0.)
    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)), 
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)), 
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)),
])
    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)

    # Remember to use notebook=False when you write a script to be run in a terminal
    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

    L2_outputs[f'L2_{penalty_coeff}'] = [penalty_coeff, stats.tolist(), keys, run_time]

    fig_1.savefig(os.path.join(FIGURES_PATH, f'err_L2_{penalty_coeff}.png'))
    fig_2.savefig(os.path.join(FIGURES_PATH, f'acc_L2_{penalty_coeff}.png'))

with open(os.path.join(DATA_PATH, f'L2_data'), 'w+') as f:
    json.dump(L2_outputs, f)
# Out:
# ...
# Epoch 1: 2.0s to complete
#     error(train)=9.46e-01, acc(train)=7.05e-01, error(valid)=9.58e-01, acc(valid)=7.01e-01
# ...
# Epoch 2: 2.0s to complete
#     error(train)=7.10e-01, acc(train)=7.67e-01, error(valid)=7.30e-01, acc(valid)=7.62e-01
# ...
# Epoch 3: 2.0s to complete
#     error(train)=6.36e-01, acc(train)=7.91e-01, error(valid)=6.66e-01, acc(valid)=7.80e-01
# ...
# Epoch 4: 1.9s to complete
#     error(train)=5.77e-01, acc(train)=8.16e-01, error(valid)=6.05e-01, acc(valid)=8.05e-01
# ...
# Epoch 5: 2.0s to complete
#     error(train)=5.49e-01, acc(train)=8.16e-01, error(valid)=5.83e-01, acc(valid)=8.05e-01
# ...
# Epoch 6: 1.9s to complete
#     error(train)=5.20e-01, acc(train)=8.27e-01, error(valid)=5.52e-01, acc(valid)=8.18e-01
# ...
# Epoch 7: 2.0s to complete
#     error(train)=5.46e-01, acc(train)=8.17e-01, error(valid)=5.82e-01, acc(valid)=8.07e-01
# ...
# Epoch 8: 2.0s to complete
#     error(train)=4.96e-01, acc(train)=8.36e-01, error(valid)=5.36e-01, acc(valid)=8.20e-01
# ...
# Epoch 9: 2.1s to complete
# ...

# %% [markdown]
# # Dropout & L1

# %%
DO_L1_outputs = {}

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser
from mlp.penalties import L1Penalty

# Setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

incl_probs = [0.85, 0.9, 0.95]
penalty_coeffs = [1e-5, 5e-5, 1e-6, 5e-6]

for incl_prob in incl_probs:
    for penalty_coeff in penalty_coeffs:
        train_data.reset()
        valid_data.reset()
        weights_init = GlorotUniformInit(rng=rng)
        biases_init = ConstantInit(0.)
        model = MultipleLayerModel([
            AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng)
            AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng)
            AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng)
            AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng)
            AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=L1Penalty(penalty_coeff), biases_penalty=L1Penalty(penalty_coeff)),
])
    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)

    # Remember to use notebook=False when you write a script to be run in a terminal
    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

    DO_L1_outputs[f'DO_L1_{incl_prob}_{penalty_coeff}'] = [penalty_coeff, stats.tolist(), keys, run_time]

    fig_1.savefig(os.path.join(FIGURES_PATH, f'DO_L1_{incl_prob}_{penalty_coeff}.png'))
    fig_2.savefig(os.path.join(FIGURES_PATH, f'DO_L1_{incl_prob}_{penalty_coeff}.png'))

with open(os.path.join(DATA_PATH, f'DO_L1_data'), 'w+') as f:
    json.dump(DO_L1_outputs, f)

# %% [markdown]
# # Dropout & L2

# %%
DO_L2_outputs = {}

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescentLearningRule
from mlp.optimisers import Optimiser
from mlp.penalties import L2Penalty

# Setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

incl_probs = [0.85, 0.9, 0.95]
penalty_coeffs = [1e-5, 5e-5, 1e-6, 5e-6]

for incl_prob in incl_probs:
    for penalty_coeff in penalty_coeffs:
        train_data.reset()
        valid_data.reset()
        weights_init = GlorotUniformInit(rng=rng)
        biases_init = ConstantInit(0.)
        model = MultipleLayerModel([
            AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng)
            AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng)
            AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng)
            AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)), 
            ReluLayer(),
            DropoutLayer(incl_prob = incl_prob, rng=rng)
            AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=L2Penalty(penalty_coeff), biases_penalty=L2Penalty(penalty_coeff)),
])
    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate = learning_rate)

    # Remember to use notebook=False when you write a script to be run in a terminal
    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

    DO_L2_outputs[f'DO_L2_{incl_prob}_{penalty_coeff}'] = [penalty_coeff, stats.tolist(), keys, run_time]

    fig_1.savefig(os.path.join(FIGURES_PATH, f'DO_L2_{incl_prob}_{penalty_coeff}.png'))
    fig_2.savefig(os.path.join(FIGURES_PATH, f'DO_L2_{incl_prob}_{penalty_coeff}.png'))

with open(os.path.join(DATA_PATH, f'DO_L2_data'), 'w+') as f:
    json.dump(DO_L2_outputs, f)

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule, GradientDescent 
from mlp.optimisers import Optimiser
from mlp.penalties import L1Penalty, L2Penalty

#setup hyperparameters
grid = product(learning_rate, dropout_prob, penalty_coeff, penalty, share_across_batch)
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128


for learning_rate, dropout_prob, penalty_coeff, penalty in grid:
    train_data.reset()
    valid_data.reset()
    if penalty == 'L1':
        L1Penalty()
    else:
        L2Penalty()
        penalty_obj = L1Penalty()
    weights_init = GlorotUniformInit(rng=rng)
    biases_init = ConstantInit(0.)
    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty = ), 
        ReluLayer(),
        DropoutLayer(incl_prob = incl_prob, rng=rng, share_across_batch=share_across_batch, rng = rng)
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        DropoutLayer(incl_prob = incl_prob, rng=rng, share_across_batch=share_across_batch)
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        DropoutLayer(incl_prob = incl_prob, rng=rng, share_across_batch=share_across_batch)
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = AdamLearningRule()

    #Remember to use notebook=False when you write a script to be run in a terminal
    stats, keys, run_time, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
    output[f'{hidden_dim}_3l'] = [stats, keys, run_time, fig_1, ax_1, fig_2, ax_2]
# Out:
# [(0.01, 0.1, 1e-05, 'L1'),
#  (0.01, 0.1, 1e-05, 'L2'),
#  (0.01, 0.1, 0.0001, 'L1'),
#  (0.01, 0.1, 0.0001, 'L2'),
#  (0.01, 0.1, 0.001, 'L1'),
#  (0.01, 0.1, 0.001, 'L2'),
#  (0.01, 0.1, 0.01, 'L1'),
#  (0.01, 0.1, 0.01, 'L2'),
#  (0.01, 0.1, 0.1, 'L1'),
#  (0.01, 0.1, 0.1, 'L2'),
#  (0.01, 0.3, 1e-05, 'L1'),
#  (0.01, 0.3, 1e-05, 'L2'),
#  (0.01, 0.3, 0.0001, 'L1'),
#  (0.01, 0.3, 0.0001, 'L2'),
#  (0.01, 0.3, 0.001, 'L1'),
#  (0.01, 0.3, 0.001, 'L2'),
#  (0.01, 0.3, 0.01, 'L1'),
#  (0.01, 0.3, 0.01, 'L2'),
#  (0.01, 0.3, 0.1, 'L1'),
#  (0.01, 0.3, 0.1, 'L2'),
#  (0.01, 0.5, 1e-05, 'L1'),
#  (0.01, 0.5, 1e-05, 'L2'),
#  (0.01, 0.5, 0.0001, 'L1'),
#  (0.01, 0.5, 0.0001, 'L2'),
#  (0.01, 0.5, 0.001, 'L1'),
#  (0.01, 0.5, 0.001, 'L2'),
#  (0.01, 0.5, 0.01, 'L1'),
#  (0.01, 0.5, 0.01, 'L2'),
#  (0.01, 0.5, 0.1, 'L1'),
#  (0.01, 0.5, 0.1, 'L2'),
#  (0.01, 0.8, 1e-05, 'L1'),
#  (0.01, 0.8, 1e-05, 'L2'),
#  (0.01, 0.8, 0.0001, 'L1'),
#  (0.01, 0.8, 0.0001, 'L2'),
# ...

# %%
# Plotting learning rate (x) vs. loss per mini-batch (y)
